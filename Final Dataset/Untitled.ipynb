# %%
import pandas as pd
data = pd.read_csv("FINAL_COMBINED_DATASET.csv")

data.head(10)
# Out:
#            image                                            caption  \
# 0  img000000.jpg  Closeup of bins of food that include broccoli ...
# 1  img000000.jpg         A bunch of trays that have different food.
# 2  img000000.jpg  Colorful dishes holding meat, vegetables, frui...
# 3  img000000.jpg  there are containers filled with different kin...
# 4  img000000.jpg  A meal is presented in brightly colored plasti...
# 5  img000001.jpg               A giraffe standing up nearby a tree
# 6  img000001.jpg      A giraffe mother with its baby in the forest.
# 7  img000001.jpg       Two giraffes standing in a tree filled area.
# 8  img000001.jpg  A giraffe standing next to a forest filled wit...
# 9  img000001.jpg    A giraffe eating food from the top of the tree.
#
#                                         urdu_caption
# 0  کھانے کے ڈبوں کا کلوز اپ جس میں بروکولی اور رو...
# 1       ٹرے کا ایک گروپ جس میں مختلف کھانے ہوتے ہیں۔
# 2  رنگ برنگے پکوان جن میں گوشت، سبزیاں، پھل اور ر...
# ...

# %%
display(data.head(20))
# Out:
#             image  \
# 0   img000000.jpg
# 1   img000000.jpg
# 2   img000000.jpg
# 3   img000000.jpg
# 4   img000000.jpg
# 5   img000001.jpg
# 6   img000001.jpg
# 7   img000001.jpg
# 8   img000001.jpg
# 9   img000001.jpg
# 10  img000002.jpg
# 11  img000002.jpg
# 12  img000002.jpg
# 13  img000002.jpg
# 14  img000002.jpg
# 15  img000003.jpg
# 16  img000003.jpg
# 17  img000003.jpg
# 18  img000003.jpg
# 19  img000003.jpg
#
#                                                              caption  \
# 0           Closeup of bins of food that include broccoli and bread.
# 1                         A bunch of trays that have different food.
# 2        Colorful dishes holding meat, vegetables, fruit, and bread.
# 3          there are containers filled with different kinds of foods
# 4             A meal is presented in brightly colored plastic trays.
# 5                               A giraffe standing up nearby a tree
# 6                      A giraffe mother with its baby in the forest.
# ...

# %%
pd.set_option("max_colwidt", None)
